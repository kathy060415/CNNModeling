# %% [markdown]
# **Transfer learning**
#
# InceptionV3
#
# knowledge being reused for another similar dataset or task
#
# https://people.minesparis.psl.eu/fabien.moutarde/ES_LSML/TP_TransferLearning-ConvNet/transfer_learning.html

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import SGD

# %%
USE_TENSORFLOW_AS_BACKEND = True

# %%
# %matplotlib inline
from scipy import misc
import seaborn

# %%
if USE_TENSORFLOW_AS_BACKEND:
    os.environ['KERAS_BACKEND'] = 'tensorflow'
else:
    os.environ['KERAS_BACKEND'] = 'theano'

# %%
import keras
from keras import backend as K
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications import MobileNetV3Large, MobileNetV3Small
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.utils import np_utils

# %% [markdown]
# **Dataset**

# %%
# ![[ -f 101_ObjectCategories ]] || tar -xvzf 101_ObjectCategories.tar.gz

# %%
# !unzip 101_ObjectCategories.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0241.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0242.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0243.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0244.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0245.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0246.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0247.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0248.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0249.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0250.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0251.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0252.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0253.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0254.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0255.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0256.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0257.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0258.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0259.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0260.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0261.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0262.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0263.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0264.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0265.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0266.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0267.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0268.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0269.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0270.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0271.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0272.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0273.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0274.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0275.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0276.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0277.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0278.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0279.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0280.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0281.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0282.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0283.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0284.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0285.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0286.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0287.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0288.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0289.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0290.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0291.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0292.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0293.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0294.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0295.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0296.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0297.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0298.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0299.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0300.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0301.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0302.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0303.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0304.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0305.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0306.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0307.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0308.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0309.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0310.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0311.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0312.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0313.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0314.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0315.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0316.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0317.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0318.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0319.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0320.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0321.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0322.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0323.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0324.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0325.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0326.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0327.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0328.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0329.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0330.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0331.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0332.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0333.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0334.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0335.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0336.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0337.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0338.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0339.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0340.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0341.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0342.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0343.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0344.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0345.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0346.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0347.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0348.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0349.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0350.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0351.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0352.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0353.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0354.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0355.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0356.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0357.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0358.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0359.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0360.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0361.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0362.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0363.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0364.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0365.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0366.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0367.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0368.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0369.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0370.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0371.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0372.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0373.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0374.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0375.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0376.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0377.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0378.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0379.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0380.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0381.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0382.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0383.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0384.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0385.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0386.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0387.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0388.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0389.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0390.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0391.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0392.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0393.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0394.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0395.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0396.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0397.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0398.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0399.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0400.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0401.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0402.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0403.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0404.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0405.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0406.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0407.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0408.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0409.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0410.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0411.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0412.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0413.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0414.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0415.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0416.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0417.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0418.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0419.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0420.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0421.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0422.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0423.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0424.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0425.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0426.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0427.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0428.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0429.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0430.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0431.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0432.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0433.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0434.jpg
#   inflating: /content/101_ObjectCategories/Faces_easy/image_0435.jpg
#    creating: /content/101_ObjectCategories/ferry/
#   inflating: /content/101_ObjectCategories/ferry/image_0001.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0002.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0003.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0004.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0005.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0006.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0007.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0008.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0009.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0010.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0011.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0012.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0013.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0014.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0015.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0016.jpg
#  extracting: /content/101_ObjectCategories/ferry/image_0017.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0018.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0019.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0020.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0021.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0022.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0023.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0024.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0025.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0026.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0027.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0028.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0029.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0030.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0031.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0032.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0033.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0034.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0035.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0036.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0037.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0038.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0039.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0040.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0041.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0042.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0043.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0044.jpg
#  extracting: /content/101_ObjectCategories/ferry/image_0045.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0046.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0047.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0048.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0049.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0050.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0051.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0052.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0053.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0054.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0055.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0056.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0057.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0058.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0059.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0060.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0061.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0062.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0063.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0064.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0065.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0066.jpg
#   inflating: /content/101_ObjectCategories/ferry/image_0067.jpg
#    creating: /content/101_ObjectCategories/flamingo/
#   inflating: /content/101_ObjectCategories/flamingo/image_0001.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0002.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0003.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0004.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0005.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0006.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0007.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0008.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0009.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0010.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0011.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0012.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0013.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0014.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0015.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0016.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0017.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0018.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0019.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0020.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0021.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0022.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0023.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0024.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0025.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0026.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0027.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0028.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0029.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0030.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0031.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0032.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0033.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0034.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0035.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0036.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0037.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0038.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0039.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0040.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0041.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0042.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0043.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0044.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0045.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0046.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0047.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0048.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0049.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0050.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0051.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0052.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0053.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0054.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0055.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0056.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0057.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0058.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0059.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0060.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0061.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0062.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0063.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0064.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0065.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0066.jpg
#   inflating: /content/101_ObjectCategories/flamingo/image_0067.jpg
#    creating: /content/101_ObjectCategories/flamingo_head/
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0001.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0002.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0003.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0004.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0005.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0006.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0007.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0008.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0009.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0010.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0011.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0012.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0013.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0014.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0015.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0016.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0017.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0018.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0019.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0020.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0021.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0022.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0023.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0024.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0025.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0026.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0027.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0028.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0029.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0030.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0031.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0032.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0033.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0034.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0035.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0036.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0037.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0038.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0039.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0040.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0041.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0042.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0043.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0044.jpg
#   inflating: /content/101_ObjectCategories/flamingo_head/image_0045.jpg
#    creating: /content/101_ObjectCategories/garfield/
#   inflating: /content/101_ObjectCategories/garfield/image_0001.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0002.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0003.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0004.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0005.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0006.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0007.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0008.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0009.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0010.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0011.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0012.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0013.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0014.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0015.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0016.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0017.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0018.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0019.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0020.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0021.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0022.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0023.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0024.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0025.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0026.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0027.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0028.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0029.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0030.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0031.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0032.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0033.jpg
#   inflating: /content/101_ObjectCategories/garfield/image_0034.jpg
#    creating: /content/101_ObjectCategories/gerenuk/
#   inflating: /content/101_ObjectCategories/gerenuk/image_0001.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0002.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0003.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0004.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0005.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0006.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0007.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0008.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0009.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0010.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0011.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0012.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0013.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0014.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0015.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0016.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0017.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0018.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0019.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0020.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0021.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0022.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0023.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0024.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0025.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0026.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0027.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0028.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0029.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0030.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0031.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0032.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0033.jpg
#   inflating: /content/101_ObjectCategories/gerenuk/image_0034.jpg
#    creating: /content/101_ObjectCategories/gramophone/
#   inflating: /content/101_ObjectCategories/gramophone/image_0001.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0002.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0003.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0004.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0005.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0006.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0007.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0008.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0009.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0010.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0011.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0012.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0013.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0014.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0015.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0016.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0017.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0018.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0019.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0020.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0021.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0022.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0023.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0024.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0025.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0026.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0027.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0028.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0029.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0030.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0031.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0032.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0033.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0034.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0035.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0036.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0037.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0038.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0039.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0040.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0041.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0042.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0043.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0044.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0045.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0046.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0047.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0048.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0049.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0050.jpg
#   inflating: /content/101_ObjectCategories/gramophone/image_0051.jpg
#    creating: /content/101_ObjectCategories/grand_piano/
#   inflating: /content/101_ObjectCategories/grand_piano/image_0001.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0002.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0003.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0004.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0005.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0006.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0007.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0008.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0009.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0010.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0011.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0012.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0013.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0014.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0015.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0016.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0017.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0018.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0019.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0020.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0021.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0022.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0023.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0024.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0025.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0026.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0027.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0028.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0029.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0030.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0031.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0032.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0033.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0034.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0035.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0036.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0037.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0038.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0039.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0040.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0041.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0042.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0043.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0044.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0045.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0046.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0047.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0048.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0049.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0050.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0051.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0052.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0053.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0054.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0055.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0056.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0057.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0058.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0059.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0060.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0061.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0062.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0063.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0064.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0065.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0066.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0067.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0068.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0069.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0070.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0071.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0072.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0073.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0074.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0075.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0076.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0077.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0078.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0079.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0080.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0081.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0082.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0083.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0084.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0085.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0086.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0087.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0088.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0089.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0090.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0091.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0092.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0093.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0094.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0095.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0096.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0097.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0098.jpg
#   inflating: /content/101_ObjectCategories/grand_piano/image_0099.jpg
#    creating: /content/101_ObjectCategories/hawksbill/
#   inflating: /content/101_ObjectCategories/hawksbill/image_0001.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0002.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0003.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0004.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0005.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0006.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0007.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0008.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0009.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0010.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0011.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0012.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0013.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0014.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0015.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0016.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0017.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0018.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0019.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0020.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0021.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0022.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0023.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0024.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0025.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0026.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0027.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0028.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0029.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0030.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0031.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0032.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0033.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0034.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0035.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0036.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0037.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0038.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0039.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0040.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0041.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0042.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0043.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0044.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0045.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0046.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0047.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0048.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0049.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0050.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0051.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0052.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0053.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0054.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0055.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0056.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0057.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0058.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0059.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0060.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0061.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0062.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0063.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0064.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0065.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0066.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0067.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0068.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0069.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0070.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0071.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0072.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0073.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0074.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0075.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0076.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0077.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0078.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0079.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0080.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0081.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0082.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0083.jpg
#   inflating: /content/101_ObjectCategories/hawksbill/image_0084.jpg
# ...
#   inflating: /content/101_ObjectCategories/wheelchair/image_0025.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0026.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0027.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0028.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0029.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0030.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0031.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0032.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0033.jpg
#  extracting: /content/101_ObjectCategories/wheelchair/image_0034.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0035.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0036.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0037.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0038.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0039.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0040.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0041.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0042.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0043.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0044.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0045.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0046.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0047.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0048.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0049.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0050.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0051.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0052.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0053.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0054.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0055.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0056.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0057.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0058.jpg
#   inflating: /content/101_ObjectCategories/wheelchair/image_0059.jpg
#    creating: /content/101_ObjectCategories/wild_cat/
#   inflating: /content/101_ObjectCategories/wild_cat/image_0001.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0002.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0003.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0004.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0005.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0006.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0007.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0008.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0009.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0010.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0011.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0012.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0013.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0014.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0015.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0016.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0017.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0018.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0019.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0020.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0021.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0022.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0023.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0024.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0025.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0026.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0027.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0028.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0029.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0030.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0031.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0032.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0033.jpg
#   inflating: /content/101_ObjectCategories/wild_cat/image_0034.jpg
#    creating: /content/101_ObjectCategories/windsor_chair/
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0001.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0002.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0003.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0004.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0005.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0006.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0007.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0008.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0009.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0010.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0011.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0012.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0013.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0014.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0015.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0016.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0017.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0018.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0019.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0020.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0021.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0022.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0023.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0024.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0025.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0026.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0027.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0028.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0029.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0030.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0031.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0032.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0033.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0034.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0035.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0036.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0037.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0038.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0039.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0040.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0041.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0042.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0043.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0044.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0045.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0046.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0047.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0048.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0049.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0050.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0051.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0052.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0053.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0054.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0055.jpg
#   inflating: /content/101_ObjectCategories/windsor_chair/image_0056.jpg
#    creating: /content/101_ObjectCategories/wrench/
#   inflating: /content/101_ObjectCategories/wrench/image_0001.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0002.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0003.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0004.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0005.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0006.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0007.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0008.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0009.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0010.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0011.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0012.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0013.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0014.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0015.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0016.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0017.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0018.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0019.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0020.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0021.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0022.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0023.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0024.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0025.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0026.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0027.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0028.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0029.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0030.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0031.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0032.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0033.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0034.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0035.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0036.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0037.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0038.jpg
#   inflating: /content/101_ObjectCategories/wrench/image_0039.jpg
#    creating: /content/101_ObjectCategories/yin_yang/
#   inflating: /content/101_ObjectCategories/yin_yang/image_0001.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0002.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0003.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0004.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0005.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0006.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0007.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0008.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0009.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0010.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0011.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0012.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0013.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0014.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0015.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0016.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0017.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0018.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0019.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0020.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0021.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0022.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0023.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0024.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0025.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0026.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0027.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0028.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0029.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0030.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0031.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0032.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0033.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0034.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0035.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0036.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0037.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0038.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0039.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0040.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0041.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0042.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0043.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0044.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0045.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0046.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0047.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0048.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0049.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0050.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0051.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0052.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0053.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0054.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0055.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0056.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0057.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0058.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0059.jpg
#   inflating: /content/101_ObjectCategories/yin_yang/image_0060.jpg

# %%
# !ls 101_ObjectCategories
# Out:
# accordion	   cougar_body	    garfield	  menorah     snoopy
# airplanes	   cougar_face	    gerenuk	  metronome   soccer_ball
# anchor		   crab		    gramophone	  minaret     stapler
# ant		   crayfish	    grand_piano   Motorbikes  starfish
# BACKGROUND_Google  crocodile	    hawksbill	  nautilus    stegosaurus
# barrel		   crocodile_head   headphone	  octopus     stop_sign
# bass		   cup		    hedgehog	  okapi       strawberry
# beaver		   dalmatian	    helicopter	  pagoda      sunflower
# binocular	   dollar_bill	    ibis	  panda       tick
# bonsai		   dolphin	    inline_skate  pigeon      trilobite
# brain		   dragonfly	    joshua_tree   pizza       umbrella
# brontosaurus	   electric_guitar  kangaroo	  platypus    watch
# buddha		   elephant	    ketch	  pyramid     water_lilly
# butterfly	   emu		    lamp	  revolver    wheelchair
# camera		   euphonium	    laptop	  rhino       wild_cat
# cannon		   ewer		    Leopards	  rooster     windsor_chair
# car_side	   Faces	    llama	  saxophone   wrench
# ceiling_fan	   Faces_easy	    lobster	  schooner    yin_yang
# cellphone	   ferry	    lotus	  scissors
# chair		   flamingo	    mandolin	  scorpion
# chandelier	   flamingo_head    mayfly	  sea_horse

# %%
# !pip install scipy==1.2.2
# Out:
# Collecting scipy==1.2.2
#   Downloading scipy-1.2.2-cp37-cp37m-manylinux1_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 1.5 MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.2.2) (1.21.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.2.2

# %% [markdown]
# **Data preprocessing**

# %%
# functions to load the data
# def load_batch_images(path, n_examples_train, n_examples_validation=2, max_imgs_by_class=30, nb_categories=4, resize_to_size=(224,224)):

def load_batch_images(path, n_examples_train, n_examples_validation=2, max_imgs_by_class=30, nb_categories=4, resize_to_size=(224,224)):

    images_train = []
    labels_train = []
    images_validation = []
    labels_validation = []
    
    # Get categories from path
    categories_list = os.listdir(path)
    categories_list = [category for category in categories_list if category != '.DS_Store']
    if isinstance(nb_categories, int) and len(categories_list) >= nb_categories:
        categories_list = categories_list[0:nb_categories]

    # For each category...
    for idx, category in enumerate(categories_list):
        # ... get images in category ...
        images_list = os.listdir(os.path.join(path, category))        
        if len(images_list) > max_imgs_by_class:
            images_list = images_list[:max_imgs_by_class]
        
        indx = 0
        for images in images_list[:n_examples_train + n_examples_validation]:                
            # ... load them ...
            img = load_img(os.path.join(path, category, images))  # as PIL images
            img = img_to_array(img)                               # as numpy array
            img = misc.imresize(img, resize_to_size)              # resize
            # img = misc.imrotate(img, 180)
            if indx < n_examples_train:
                images_train.append(img)
                labels_train.append(idx)
            else:
                images_validation.append(img)
                labels_validation.append(idx)
            indx += 1
    
    # Convert to one-hot
    labels_train = np_utils.to_categorical(labels_train)
    labels_validation = np_utils.to_categorical(labels_validation)

    return images_train, labels_train, images_validation, labels_validation

# %%
def shuffle_dataset(a, b):
    """Shuffle the entire dataset"""
    assert np.shape(a)[0] == np.shape(b)[0]
    p = np.random.permutation(np.shape(a)[0])
    return (a[p], b[p])

# %%
def get_data(samples_by_category=8, dataset_path="./101_ObjectCategories/", nb_categories=4):
    images_train, labels_train, images_validation, labels_validation = load_batch_images(path=dataset_path, n_examples_train=samples_by_category, n_examples_validation=20, max_imgs_by_class=30, nb_categories=nb_categories)

    images_train = np.float64(images_train)
    images_validation = np.float64(images_validation)

    images_train = preprocess_input(images_train)  # substract the mean RGB channels of the imagenet dataset. This is because the Inception model we are using has been trained on a different dataset (imagenet dataset)
    images_validation = preprocess_input(images_validation)

    if not USE_TENSORFLOW_AS_BACKEND:
        images_validation = images_validation.swapaxes(1, 3).swapaxes(2, 3)
        images_train = images_train.swapaxes(1, 3).swapaxes(2, 3)

    train = shuffle_dataset(np.asarray(images_train), labels_train)
    validation = shuffle_dataset(np.asarray(images_validation), labels_validation)

    images_train, labels_train = train
    images_validation, labels_validation = validation

    return images_train, labels_train, train, images_validation, labels_validation, validation

# %%
def demo_plot():
    demo_path = "./101_ObjectCategories/"

    demo_data, _, _, _ = load_batch_images(path=demo_path, n_examples_train=8, n_examples_validation=20)
    f, axarr = plt.subplots(2,2)
    axarr[0,0].imshow(demo_data[0])
    axarr[1,0].imshow(demo_data[1])
    axarr[0,1].imshow(demo_data[27])
    axarr[1,1].imshow(demo_data[31])
    axarr[0,0].grid('off')
    axarr[0,1].grid('off')
    axarr[1,0].grid('off')
    axarr[1,1].grid('off')
    plt.show()

# %%
demo_plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.

# %%
nb_categories = 4  #4         # out of 101 classes
samples_by_category = 10  # out of about 50 images for each category

# Load the data!
train_img, train_labels, train, val_img, val_labels, val = get_data(samples_by_category=samples_by_category, dataset_path='./101_ObjectCategories/', nb_categories=nb_categories)

# # Normalize pixel values to be between 0 and 1
# train_img, val_img = train_img / 255.0, val_img / 255.0

# Print the tensors shapes
print('Shapes (train) :', train_img[0].shape, train_labels[0].shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
# Shapes (train) : (224, 224, 3) (4,)

# %%
base_model = InceptionV3(weights='imagenet', include_top=False)

# %%
# print all the layers
base_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  batch_normalization (BatchNorm  (None, None, None,   96         ['conv2d[0][0]']
#  alization)                     32)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 32)
#
#  conv2d_1 (Conv2D)              (None, None, None,   9216        ['activation[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   96         ['conv2d_1[0][0]']
#  rmalization)                   32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   18432       ['activation_1[0][0]']
#                                 64)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   192        ['conv2d_2[0][0]']
#  rmalization)                   64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['activation_2[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   5120        ['max_pooling2d[0][0]']
#                                 80)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   240        ['conv2d_3[0][0]']
#  rmalization)                   80)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 80)
#
#  conv2d_4 (Conv2D)              (None, None, None,   138240      ['activation_3[0][0]']
#                                 192)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   576        ['conv2d_4[0][0]']
#  rmalization)                   192)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 192)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 192)
#
#  conv2d_8 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   192        ['conv2d_8[0][0]']
#  rmalization)                   64)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 64)
#
#  conv2d_6 (Conv2D)              (None, None, None,   9216        ['max_pooling2d_1[0][0]']
#                                 48)
#
#  conv2d_9 (Conv2D)              (None, None, None,   55296       ['activation_8[0][0]']
#                                 96)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   144        ['conv2d_6[0][0]']
#  rmalization)                   48)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   288        ['conv2d_9[0][0]']
#  rmalization)                   96)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 48)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 96)
#
#  average_pooling2d (AveragePool  (None, None, None,   0          ['max_pooling2d_1[0][0]']
#  ing2D)                         192)
#
#  conv2d_5 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  conv2d_7 (Conv2D)              (None, None, None,   76800       ['activation_6[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   82944       ['activation_9[0][0]']
#                                 96)
#
#  conv2d_11 (Conv2D)             (None, None, None,   6144        ['average_pooling2d[0][0]']
#                                 32)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   192        ['conv2d_5[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   192        ['conv2d_7[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_10 (BatchN  (None, None, None,   288        ['conv2d_10[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_11 (BatchN  (None, None, None,   96         ['conv2d_11[0][0]']
#  ormalization)                  32)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 64)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 96)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_5[0][0]',
#                                 256)                              'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_15 (BatchN  (None, None, None,   192        ['conv2d_15[0][0]']
#  ormalization)                  64)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 64)
#
#  conv2d_13 (Conv2D)             (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_16 (Conv2D)             (None, None, None,   55296       ['activation_15[0][0]']
#                                 96)
#
#  batch_normalization_13 (BatchN  (None, None, None,   144        ['conv2d_13[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_16 (BatchN  (None, None, None,   288        ['conv2d_16[0][0]']
#  ormalization)                  96)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 48)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 96)
#
#  average_pooling2d_1 (AveragePo  (None, None, None,   0          ['mixed0[0][0]']
#  oling2D)                       256)
#
#  conv2d_12 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_14 (Conv2D)             (None, None, None,   76800       ['activation_13[0][0]']
#                                 64)
#
#  conv2d_17 (Conv2D)             (None, None, None,   82944       ['activation_16[0][0]']
#                                 96)
#
#  conv2d_18 (Conv2D)             (None, None, None,   16384       ['average_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_12 (BatchN  (None, None, None,   192        ['conv2d_12[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_14 (BatchN  (None, None, None,   192        ['conv2d_14[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_17 (BatchN  (None, None, None,   288        ['conv2d_17[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_18 (BatchN  (None, None, None,   192        ['conv2d_18[0][0]']
#  ormalization)                  64)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 64)
#
#  activation_14 (Activation)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 64)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 96)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_12[0][0]',
#                                 288)                              'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_22 (BatchN  (None, None, None,   192        ['conv2d_22[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 64)
#
#  conv2d_20 (Conv2D)             (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_23 (Conv2D)             (None, None, None,   55296       ['activation_22[0][0]']
#                                 96)
#
#  batch_normalization_20 (BatchN  (None, None, None,   144        ['conv2d_20[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_23 (BatchN  (None, None, None,   288        ['conv2d_23[0][0]']
#  ormalization)                  96)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 48)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 96)
#
#  average_pooling2d_2 (AveragePo  (None, None, None,   0          ['mixed1[0][0]']
#  oling2D)                       288)
#
#  conv2d_19 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_21 (Conv2D)             (None, None, None,   76800       ['activation_20[0][0]']
#                                 64)
#
#  conv2d_24 (Conv2D)             (None, None, None,   82944       ['activation_23[0][0]']
#                                 96)
#
#  conv2d_25 (Conv2D)             (None, None, None,   18432       ['average_pooling2d_2[0][0]']
#                                 64)
#
#  batch_normalization_19 (BatchN  (None, None, None,   192        ['conv2d_19[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   192        ['conv2d_21[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_24 (BatchN  (None, None, None,   288        ['conv2d_24[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_25 (BatchN  (None, None, None,   192        ['conv2d_25[0][0]']
#  ormalization)                  64)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 64)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 64)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 96)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_19[0][0]',
#                                 288)                              'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_27 (BatchN  (None, None, None,   192        ['conv2d_27[0][0]']
#  ormalization)                  64)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 64)
#
#  conv2d_28 (Conv2D)             (None, None, None,   55296       ['activation_27[0][0]']
#                                 96)
#
#  batch_normalization_28 (BatchN  (None, None, None,   288        ['conv2d_28[0][0]']
#  ormalization)                  96)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 96)
#
#  conv2d_26 (Conv2D)             (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_29 (Conv2D)             (None, None, None,   82944       ['activation_28[0][0]']
#                                 96)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1152       ['conv2d_26[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_29 (BatchN  (None, None, None,   288        ['conv2d_29[0][0]']
#  ormalization)                  96)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 384)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 96)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['mixed2[0][0]']
#                                 288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_26[0][0]',
#                                 768)                              'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_34 (BatchN  (None, None, None,   384        ['conv2d_34[0][0]']
#  ormalization)                  128)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 128)
#
#  conv2d_35 (Conv2D)             (None, None, None,   114688      ['activation_34[0][0]']
#                                 128)
#
#  batch_normalization_35 (BatchN  (None, None, None,   384        ['conv2d_35[0][0]']
#  ormalization)                  128)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 128)
#
#  conv2d_31 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_36 (Conv2D)             (None, None, None,   114688      ['activation_35[0][0]']
#                                 128)
#
#  batch_normalization_31 (BatchN  (None, None, None,   384        ['conv2d_31[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_36 (BatchN  (None, None, None,   384        ['conv2d_36[0][0]']
#  ormalization)                  128)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 128)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 128)
#
#  conv2d_32 (Conv2D)             (None, None, None,   114688      ['activation_31[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   114688      ['activation_36[0][0]']
#                                 128)
#
#  batch_normalization_32 (BatchN  (None, None, None,   384        ['conv2d_32[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_37 (BatchN  (None, None, None,   384        ['conv2d_37[0][0]']
#  ormalization)                  128)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 128)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 128)
#
#  average_pooling2d_3 (AveragePo  (None, None, None,   0          ['mixed3[0][0]']
#  oling2D)                       768)
#
#  conv2d_30 (Conv2D)             (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_33 (Conv2D)             (None, None, None,   172032      ['activation_32[0][0]']
#                                 192)
#
#  conv2d_38 (Conv2D)             (None, None, None,   172032      ['activation_37[0][0]']
#                                 192)
#
#  conv2d_39 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_3[0][0]']
#                                 192)
#
#  batch_normalization_30 (BatchN  (None, None, None,   576        ['conv2d_30[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_33 (BatchN  (None, None, None,   576        ['conv2d_33[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_38 (BatchN  (None, None, None,   576        ['conv2d_38[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_39 (BatchN  (None, None, None,   576        ['conv2d_39[0][0]']
#  ormalization)                  192)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 192)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 192)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 192)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_30[0][0]',
#                                 768)                              'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_44 (BatchN  (None, None, None,   480        ['conv2d_44[0][0]']
#  ormalization)                  160)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 160)
#
#  conv2d_45 (Conv2D)             (None, None, None,   179200      ['activation_44[0][0]']
#                                 160)
#
#  batch_normalization_45 (BatchN  (None, None, None,   480        ['conv2d_45[0][0]']
#  ormalization)                  160)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 160)
#
#  conv2d_41 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_46 (Conv2D)             (None, None, None,   179200      ['activation_45[0][0]']
#                                 160)
#
#  batch_normalization_41 (BatchN  (None, None, None,   480        ['conv2d_41[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_46 (BatchN  (None, None, None,   480        ['conv2d_46[0][0]']
#  ormalization)                  160)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 160)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 160)
#
#  conv2d_42 (Conv2D)             (None, None, None,   179200      ['activation_41[0][0]']
#                                 160)
#
#  conv2d_47 (Conv2D)             (None, None, None,   179200      ['activation_46[0][0]']
#                                 160)
#
#  batch_normalization_42 (BatchN  (None, None, None,   480        ['conv2d_42[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_47 (BatchN  (None, None, None,   480        ['conv2d_47[0][0]']
#  ormalization)                  160)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 160)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 160)
#
#  average_pooling2d_4 (AveragePo  (None, None, None,   0          ['mixed4[0][0]']
#  oling2D)                       768)
#
#  conv2d_40 (Conv2D)             (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_43 (Conv2D)             (None, None, None,   215040      ['activation_42[0][0]']
#                                 192)
#
#  conv2d_48 (Conv2D)             (None, None, None,   215040      ['activation_47[0][0]']
#                                 192)
#
#  conv2d_49 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_4[0][0]']
#                                 192)
#
#  batch_normalization_40 (BatchN  (None, None, None,   576        ['conv2d_40[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_43 (BatchN  (None, None, None,   576        ['conv2d_43[0][0]']
# ...
#
#  conv2d_82 (Conv2D)             (None, None, None,   442368      ['activation_81[0][0]']
#                                 384)
#
#  conv2d_83 (Conv2D)             (None, None, None,   442368      ['activation_81[0][0]']
#                                 384)
#
#  average_pooling2d_7 (AveragePo  (None, None, None,   0          ['mixed8[0][0]']
#  oling2D)                       1280)
#
#  conv2d_76 (Conv2D)             (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_78 (BatchN  (None, None, None,   1152       ['conv2d_78[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_79 (BatchN  (None, None, None,   1152       ['conv2d_79[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_82 (BatchN  (None, None, None,   1152       ['conv2d_82[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_83 (BatchN  (None, None, None,   1152       ['conv2d_83[0][0]']
#  ormalization)                  384)
#
#  conv2d_84 (Conv2D)             (None, None, None,   245760      ['average_pooling2d_7[0][0]']
#                                 192)
#
#  batch_normalization_76 (BatchN  (None, None, None,   960        ['conv2d_76[0][0]']
#  ormalization)                  320)
#
#  activation_78 (Activation)     (None, None, None,   0           ['batch_normalization_78[0][0]']
#                                 384)
#
#  activation_79 (Activation)     (None, None, None,   0           ['batch_normalization_79[0][0]']
#                                 384)
#
#  activation_82 (Activation)     (None, None, None,   0           ['batch_normalization_82[0][0]']
#                                 384)
#
#  activation_83 (Activation)     (None, None, None,   0           ['batch_normalization_83[0][0]']
#                                 384)
#
#  batch_normalization_84 (BatchN  (None, None, None,   576        ['conv2d_84[0][0]']
#  ormalization)                  192)
#
#  activation_76 (Activation)     (None, None, None,   0           ['batch_normalization_76[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_78[0][0]',
#                                 768)                              'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, None, None,   0           ['activation_82[0][0]',
#                                 768)                              'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, None, None,   0           ['batch_normalization_84[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_76[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_89 (BatchN  (None, None, None,   1344       ['conv2d_89[0][0]']
#  ormalization)                  448)
#
#  activation_89 (Activation)     (None, None, None,   0           ['batch_normalization_89[0][0]']
#                                 448)
#
#  conv2d_86 (Conv2D)             (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_90 (Conv2D)             (None, None, None,   1548288     ['activation_89[0][0]']
#                                 384)
#
#  batch_normalization_86 (BatchN  (None, None, None,   1152       ['conv2d_86[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_90 (BatchN  (None, None, None,   1152       ['conv2d_90[0][0]']
#  ormalization)                  384)
#
#  activation_86 (Activation)     (None, None, None,   0           ['batch_normalization_86[0][0]']
#                                 384)
#
#  activation_90 (Activation)     (None, None, None,   0           ['batch_normalization_90[0][0]']
#                                 384)
#
#  conv2d_87 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_88 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_91 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  conv2d_92 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  average_pooling2d_8 (AveragePo  (None, None, None,   0          ['mixed9[0][0]']
#  oling2D)                       2048)
#
#  conv2d_85 (Conv2D)             (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_87 (BatchN  (None, None, None,   1152       ['conv2d_87[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_88 (BatchN  (None, None, None,   1152       ['conv2d_88[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_91 (BatchN  (None, None, None,   1152       ['conv2d_91[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_92 (BatchN  (None, None, None,   1152       ['conv2d_92[0][0]']
#  ormalization)                  384)
#
#  conv2d_93 (Conv2D)             (None, None, None,   393216      ['average_pooling2d_8[0][0]']
#                                 192)
#
#  batch_normalization_85 (BatchN  (None, None, None,   960        ['conv2d_85[0][0]']
#  ormalization)                  320)
#
#  activation_87 (Activation)     (None, None, None,   0           ['batch_normalization_87[0][0]']
#                                 384)
#
#  activation_88 (Activation)     (None, None, None,   0           ['batch_normalization_88[0][0]']
#                                 384)
#
#  activation_91 (Activation)     (None, None, None,   0           ['batch_normalization_91[0][0]']
#                                 384)
#
#  activation_92 (Activation)     (None, None, None,   0           ['batch_normalization_92[0][0]']
#                                 384)
#
#  batch_normalization_93 (BatchN  (None, None, None,   576        ['conv2d_93[0][0]']
#  ormalization)                  192)
#
#  activation_85 (Activation)     (None, None, None,   0           ['batch_normalization_85[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_87[0][0]',
#                                 768)                              'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['activation_91[0][0]',
#                                 768)                              'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, None, None,   0           ['batch_normalization_93[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_85[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(32, activation='relu')(x)

# and a logistic layer -- we have nb_categories classes
predictions = Dense(nb_categories, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# %%
# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False
    
# print adapted model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  batch_normalization (BatchNorm  (None, None, None,   96         ['conv2d[0][0]']
#  alization)                     32)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 32)
#
#  conv2d_1 (Conv2D)              (None, None, None,   9216        ['activation[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   96         ['conv2d_1[0][0]']
#  rmalization)                   32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   18432       ['activation_1[0][0]']
#                                 64)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   192        ['conv2d_2[0][0]']
#  rmalization)                   64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['activation_2[0][0]']
#                                 64)
#
#  conv2d_3 (Conv2D)              (None, None, None,   5120        ['max_pooling2d[0][0]']
#                                 80)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   240        ['conv2d_3[0][0]']
#  rmalization)                   80)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 80)
#
#  conv2d_4 (Conv2D)              (None, None, None,   138240      ['activation_3[0][0]']
#                                 192)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   576        ['conv2d_4[0][0]']
#  rmalization)                   192)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 192)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 192)
#
#  conv2d_8 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   192        ['conv2d_8[0][0]']
#  rmalization)                   64)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 64)
#
#  conv2d_6 (Conv2D)              (None, None, None,   9216        ['max_pooling2d_1[0][0]']
#                                 48)
#
#  conv2d_9 (Conv2D)              (None, None, None,   55296       ['activation_8[0][0]']
#                                 96)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   144        ['conv2d_6[0][0]']
#  rmalization)                   48)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   288        ['conv2d_9[0][0]']
#  rmalization)                   96)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 48)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 96)
#
#  average_pooling2d (AveragePool  (None, None, None,   0          ['max_pooling2d_1[0][0]']
#  ing2D)                         192)
#
#  conv2d_5 (Conv2D)              (None, None, None,   12288       ['max_pooling2d_1[0][0]']
#                                 64)
#
#  conv2d_7 (Conv2D)              (None, None, None,   76800       ['activation_6[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   82944       ['activation_9[0][0]']
#                                 96)
#
#  conv2d_11 (Conv2D)             (None, None, None,   6144        ['average_pooling2d[0][0]']
#                                 32)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   192        ['conv2d_5[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   192        ['conv2d_7[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_10 (BatchN  (None, None, None,   288        ['conv2d_10[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_11 (BatchN  (None, None, None,   96         ['conv2d_11[0][0]']
#  ormalization)                  32)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 64)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 96)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_5[0][0]',
#                                 256)                              'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_15 (BatchN  (None, None, None,   192        ['conv2d_15[0][0]']
#  ormalization)                  64)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 64)
#
#  conv2d_13 (Conv2D)             (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_16 (Conv2D)             (None, None, None,   55296       ['activation_15[0][0]']
#                                 96)
#
#  batch_normalization_13 (BatchN  (None, None, None,   144        ['conv2d_13[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_16 (BatchN  (None, None, None,   288        ['conv2d_16[0][0]']
#  ormalization)                  96)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 48)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 96)
#
#  average_pooling2d_1 (AveragePo  (None, None, None,   0          ['mixed0[0][0]']
#  oling2D)                       256)
#
#  conv2d_12 (Conv2D)             (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_14 (Conv2D)             (None, None, None,   76800       ['activation_13[0][0]']
#                                 64)
#
#  conv2d_17 (Conv2D)             (None, None, None,   82944       ['activation_16[0][0]']
#                                 96)
#
#  conv2d_18 (Conv2D)             (None, None, None,   16384       ['average_pooling2d_1[0][0]']
#                                 64)
#
#  batch_normalization_12 (BatchN  (None, None, None,   192        ['conv2d_12[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_14 (BatchN  (None, None, None,   192        ['conv2d_14[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_17 (BatchN  (None, None, None,   288        ['conv2d_17[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_18 (BatchN  (None, None, None,   192        ['conv2d_18[0][0]']
#  ormalization)                  64)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 64)
#
#  activation_14 (Activation)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 64)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 96)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_12[0][0]',
#                                 288)                              'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_22 (BatchN  (None, None, None,   192        ['conv2d_22[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 64)
#
#  conv2d_20 (Conv2D)             (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_23 (Conv2D)             (None, None, None,   55296       ['activation_22[0][0]']
#                                 96)
#
#  batch_normalization_20 (BatchN  (None, None, None,   144        ['conv2d_20[0][0]']
#  ormalization)                  48)
#
#  batch_normalization_23 (BatchN  (None, None, None,   288        ['conv2d_23[0][0]']
#  ormalization)                  96)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 48)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 96)
#
#  average_pooling2d_2 (AveragePo  (None, None, None,   0          ['mixed1[0][0]']
#  oling2D)                       288)
#
#  conv2d_19 (Conv2D)             (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_21 (Conv2D)             (None, None, None,   76800       ['activation_20[0][0]']
#                                 64)
#
#  conv2d_24 (Conv2D)             (None, None, None,   82944       ['activation_23[0][0]']
#                                 96)
#
#  conv2d_25 (Conv2D)             (None, None, None,   18432       ['average_pooling2d_2[0][0]']
#                                 64)
#
#  batch_normalization_19 (BatchN  (None, None, None,   192        ['conv2d_19[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   192        ['conv2d_21[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_24 (BatchN  (None, None, None,   288        ['conv2d_24[0][0]']
#  ormalization)                  96)
#
#  batch_normalization_25 (BatchN  (None, None, None,   192        ['conv2d_25[0][0]']
#  ormalization)                  64)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 64)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 64)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 96)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_19[0][0]',
#                                 288)                              'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_27 (BatchN  (None, None, None,   192        ['conv2d_27[0][0]']
#  ormalization)                  64)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 64)
#
#  conv2d_28 (Conv2D)             (None, None, None,   55296       ['activation_27[0][0]']
#                                 96)
#
#  batch_normalization_28 (BatchN  (None, None, None,   288        ['conv2d_28[0][0]']
#  ormalization)                  96)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 96)
#
#  conv2d_26 (Conv2D)             (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_29 (Conv2D)             (None, None, None,   82944       ['activation_28[0][0]']
#                                 96)
#
#  batch_normalization_26 (BatchN  (None, None, None,   1152       ['conv2d_26[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_29 (BatchN  (None, None, None,   288        ['conv2d_29[0][0]']
#  ormalization)                  96)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 384)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 96)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['mixed2[0][0]']
#                                 288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_26[0][0]',
#                                 768)                              'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_34 (BatchN  (None, None, None,   384        ['conv2d_34[0][0]']
#  ormalization)                  128)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 128)
#
#  conv2d_35 (Conv2D)             (None, None, None,   114688      ['activation_34[0][0]']
#                                 128)
#
#  batch_normalization_35 (BatchN  (None, None, None,   384        ['conv2d_35[0][0]']
#  ormalization)                  128)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 128)
#
#  conv2d_31 (Conv2D)             (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_36 (Conv2D)             (None, None, None,   114688      ['activation_35[0][0]']
#                                 128)
#
#  batch_normalization_31 (BatchN  (None, None, None,   384        ['conv2d_31[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_36 (BatchN  (None, None, None,   384        ['conv2d_36[0][0]']
#  ormalization)                  128)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 128)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 128)
#
#  conv2d_32 (Conv2D)             (None, None, None,   114688      ['activation_31[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   114688      ['activation_36[0][0]']
#                                 128)
#
#  batch_normalization_32 (BatchN  (None, None, None,   384        ['conv2d_32[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_37 (BatchN  (None, None, None,   384        ['conv2d_37[0][0]']
#  ormalization)                  128)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 128)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 128)
#
#  average_pooling2d_3 (AveragePo  (None, None, None,   0          ['mixed3[0][0]']
#  oling2D)                       768)
#
#  conv2d_30 (Conv2D)             (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_33 (Conv2D)             (None, None, None,   172032      ['activation_32[0][0]']
#                                 192)
#
#  conv2d_38 (Conv2D)             (None, None, None,   172032      ['activation_37[0][0]']
#                                 192)
#
#  conv2d_39 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_3[0][0]']
#                                 192)
#
#  batch_normalization_30 (BatchN  (None, None, None,   576        ['conv2d_30[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_33 (BatchN  (None, None, None,   576        ['conv2d_33[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_38 (BatchN  (None, None, None,   576        ['conv2d_38[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_39 (BatchN  (None, None, None,   576        ['conv2d_39[0][0]']
#  ormalization)                  192)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 192)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 192)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 192)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_30[0][0]',
#                                 768)                              'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_44 (BatchN  (None, None, None,   480        ['conv2d_44[0][0]']
#  ormalization)                  160)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 160)
#
#  conv2d_45 (Conv2D)             (None, None, None,   179200      ['activation_44[0][0]']
#                                 160)
#
#  batch_normalization_45 (BatchN  (None, None, None,   480        ['conv2d_45[0][0]']
#  ormalization)                  160)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 160)
#
#  conv2d_41 (Conv2D)             (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_46 (Conv2D)             (None, None, None,   179200      ['activation_45[0][0]']
#                                 160)
#
#  batch_normalization_41 (BatchN  (None, None, None,   480        ['conv2d_41[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_46 (BatchN  (None, None, None,   480        ['conv2d_46[0][0]']
#  ormalization)                  160)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 160)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 160)
#
#  conv2d_42 (Conv2D)             (None, None, None,   179200      ['activation_41[0][0]']
#                                 160)
#
#  conv2d_47 (Conv2D)             (None, None, None,   179200      ['activation_46[0][0]']
#                                 160)
#
#  batch_normalization_42 (BatchN  (None, None, None,   480        ['conv2d_42[0][0]']
#  ormalization)                  160)
#
#  batch_normalization_47 (BatchN  (None, None, None,   480        ['conv2d_47[0][0]']
#  ormalization)                  160)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 160)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 160)
#
#  average_pooling2d_4 (AveragePo  (None, None, None,   0          ['mixed4[0][0]']
#  oling2D)                       768)
#
#  conv2d_40 (Conv2D)             (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_43 (Conv2D)             (None, None, None,   215040      ['activation_42[0][0]']
#                                 192)
#
#  conv2d_48 (Conv2D)             (None, None, None,   215040      ['activation_47[0][0]']
#                                 192)
#
#  conv2d_49 (Conv2D)             (None, None, None,   147456      ['average_pooling2d_4[0][0]']
#                                 192)
#
#  batch_normalization_40 (BatchN  (None, None, None,   576        ['conv2d_40[0][0]']
#  ormalization)                  192)
#
#  batch_normalization_43 (BatchN  (None, None, None,   576        ['conv2d_43[0][0]']
# ...
#  oling2D)                       1280)
#
#  conv2d_76 (Conv2D)             (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_78 (BatchN  (None, None, None,   1152       ['conv2d_78[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_79 (BatchN  (None, None, None,   1152       ['conv2d_79[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_82 (BatchN  (None, None, None,   1152       ['conv2d_82[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_83 (BatchN  (None, None, None,   1152       ['conv2d_83[0][0]']
#  ormalization)                  384)
#
#  conv2d_84 (Conv2D)             (None, None, None,   245760      ['average_pooling2d_7[0][0]']
#                                 192)
#
#  batch_normalization_76 (BatchN  (None, None, None,   960        ['conv2d_76[0][0]']
#  ormalization)                  320)
#
#  activation_78 (Activation)     (None, None, None,   0           ['batch_normalization_78[0][0]']
#                                 384)
#
#  activation_79 (Activation)     (None, None, None,   0           ['batch_normalization_79[0][0]']
#                                 384)
#
#  activation_82 (Activation)     (None, None, None,   0           ['batch_normalization_82[0][0]']
#                                 384)
#
#  activation_83 (Activation)     (None, None, None,   0           ['batch_normalization_83[0][0]']
#                                 384)
#
#  batch_normalization_84 (BatchN  (None, None, None,   576        ['conv2d_84[0][0]']
#  ormalization)                  192)
#
#  activation_76 (Activation)     (None, None, None,   0           ['batch_normalization_76[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_78[0][0]',
#                                 768)                              'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, None, None,   0           ['activation_82[0][0]',
#                                 768)                              'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, None, None,   0           ['batch_normalization_84[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_76[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_89 (BatchN  (None, None, None,   1344       ['conv2d_89[0][0]']
#  ormalization)                  448)
#
#  activation_89 (Activation)     (None, None, None,   0           ['batch_normalization_89[0][0]']
#                                 448)
#
#  conv2d_86 (Conv2D)             (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_90 (Conv2D)             (None, None, None,   1548288     ['activation_89[0][0]']
#                                 384)
#
#  batch_normalization_86 (BatchN  (None, None, None,   1152       ['conv2d_86[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_90 (BatchN  (None, None, None,   1152       ['conv2d_90[0][0]']
#  ormalization)                  384)
#
#  activation_86 (Activation)     (None, None, None,   0           ['batch_normalization_86[0][0]']
#                                 384)
#
#  activation_90 (Activation)     (None, None, None,   0           ['batch_normalization_90[0][0]']
#                                 384)
#
#  conv2d_87 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_88 (Conv2D)             (None, None, None,   442368      ['activation_86[0][0]']
#                                 384)
#
#  conv2d_91 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  conv2d_92 (Conv2D)             (None, None, None,   442368      ['activation_90[0][0]']
#                                 384)
#
#  average_pooling2d_8 (AveragePo  (None, None, None,   0          ['mixed9[0][0]']
#  oling2D)                       2048)
#
#  conv2d_85 (Conv2D)             (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_87 (BatchN  (None, None, None,   1152       ['conv2d_87[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_88 (BatchN  (None, None, None,   1152       ['conv2d_88[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_91 (BatchN  (None, None, None,   1152       ['conv2d_91[0][0]']
#  ormalization)                  384)
#
#  batch_normalization_92 (BatchN  (None, None, None,   1152       ['conv2d_92[0][0]']
#  ormalization)                  384)
#
#  conv2d_93 (Conv2D)             (None, None, None,   393216      ['average_pooling2d_8[0][0]']
#                                 192)
#
#  batch_normalization_85 (BatchN  (None, None, None,   960        ['conv2d_85[0][0]']
#  ormalization)                  320)
#
#  activation_87 (Activation)     (None, None, None,   0           ['batch_normalization_87[0][0]']
#                                 384)
#
#  activation_88 (Activation)     (None, None, None,   0           ['batch_normalization_88[0][0]']
#                                 384)
#
#  activation_91 (Activation)     (None, None, None,   0           ['batch_normalization_91[0][0]']
#                                 384)
#
#  activation_92 (Activation)     (None, None, None,   0           ['batch_normalization_92[0][0]']
#                                 384)
#
#  batch_normalization_93 (BatchN  (None, None, None,   576        ['conv2d_93[0][0]']
#  ormalization)                  192)
#
#  activation_85 (Activation)     (None, None, None,   0           ['batch_normalization_85[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_87[0][0]',
#                                 768)                              'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['activation_91[0][0]',
#                                 768)                              'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, None, None,   0           ['batch_normalization_93[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_85[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['mixed10[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 32)           65568       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 4)            132         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 21,868,484
# Trainable params: 65,700
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# %%
# train the model on the new data for a few epochs
history = model.fit(train_img, train_labels, batch_size=32, validation_data=(val_img, val_labels), epochs=12)
# Out:
# Epoch 1/12
# 2/2 [==============================] - 19s 3s/step - loss: 1.8466 - acc: 0.2000 - val_loss: 1.2287 - val_acc: 0.5500
# Epoch 2/12
# 2/2 [==============================] - 0s 236ms/step - loss: 0.9840 - acc: 0.6750 - val_loss: 0.7279 - val_acc: 0.8500
# Epoch 3/12
# 2/2 [==============================] - 0s 235ms/step - loss: 0.4876 - acc: 1.0000 - val_loss: 0.5177 - val_acc: 0.8875
# Epoch 4/12
# 2/2 [==============================] - 0s 238ms/step - loss: 0.2912 - acc: 1.0000 - val_loss: 0.3957 - val_acc: 0.8875
# Epoch 5/12
# 2/2 [==============================] - 0s 239ms/step - loss: 0.1705 - acc: 1.0000 - val_loss: 0.2665 - val_acc: 0.9500
# Epoch 6/12
# 2/2 [==============================] - 0s 358ms/step - loss: 0.0746 - acc: 1.0000 - val_loss: 0.2178 - val_acc: 0.9625
# Epoch 7/12
# 2/2 [==============================] - 0s 242ms/step - loss: 0.0394 - acc: 1.0000 - val_loss: 0.2176 - val_acc: 0.9375
# Epoch 8/12
# 2/2 [==============================] - 0s 241ms/step - loss: 0.0242 - acc: 1.0000 - val_loss: 0.2287 - val_acc: 0.9000
# Epoch 9/12
# 2/2 [==============================] - 0s 234ms/step - loss: 0.0178 - acc: 1.0000 - val_loss: 0.2279 - val_acc: 0.9000
# Epoch 10/12
# 2/2 [==============================] - 0s 239ms/step - loss: 0.0134 - acc: 1.0000 - val_loss: 0.2150 - val_acc: 0.9000
# Epoch 11/12
# 2/2 [==============================] - 0s 240ms/step - loss: 0.0099 - acc: 1.0000 - val_loss: 0.1991 - val_acc: 0.9125
# Epoch 12/12
# 2/2 [==============================] - 0s 240ms/step - loss: 0.0074 - acc: 1.0000 - val_loss: 0.1839 - val_acc: 0.9250

# %%
print(model.metrics_names)
print(model.evaluate(val_img, val_labels, verbose=0))
# Out:
# ['loss', 'acc']
# [0.18391916155815125, 0.925000011920929]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch for %d samples per category' % samples_by_category)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy by epoch for %d samples per category' % samples_by_category)
plt.ylabel('accuracy')
plt.legend(['train', 'test'], loc='right')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ------------------------------------

# %% [markdown]
# Transfer Learning (MobileNetV3)

# %%
base_model = MobileNetV3Small(input_shape=(224,224,3), classes=133,
                             weights="imagenet", pooling=None, include_top=False)

# %%
base_model.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 224, 224, 3)  0           ['input_3[0][0]']
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['rescaling_2[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add_54 (TFOpL  (None, 112, 112, 16  0          ['Conv/BatchNorm[0][0]']
#  ambda)                         )
#
#  re_lu_64 (ReLU)                (None, 112, 112, 16  0           ['tf.__operators__.add_54[0][0]']
#                                 )
#
#  tf.math.multiply_54 (TFOpLambd  (None, 112, 112, 16  0          ['re_lu_64[0][0]']
#  a)                             )
#
#  multiply_36 (Multiply)         (None, 112, 112, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply_54[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 113, 113, 16  0          ['multiply_36[0][0]']
#  eroPadding2D)                  )
#
#  expanded_conv/depthwise (Depth  (None, 56, 56, 16)  144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 56, 56, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_65 (ReLU)                (None, 56, 56, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_65[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_55 (TFOpL  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  ambda)                                                          nv_1[0][0]']
#
#  re_lu_66 (ReLU)                (None, 1, 1, 16)     0           ['tf.__operators__.add_55[0][0]']
#
#  tf.math.multiply_55 (TFOpLambd  (None, 1, 1, 16)    0           ['re_lu_66[0][0]']
#  a)
#
#  expanded_conv/squeeze_excite/M  (None, 56, 56, 16)  0           ['re_lu_65[0][0]',
#  ul (Multiply)                                                    'tf.math.multiply_55[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 56, 56, 16)  256         ['expanded_conv/squeeze_excite/Mu
#                                                                  l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 56, 56, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 56, 56, 72)  1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_67 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 57, 57, 72)  0           ['re_lu_67[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 28, 28, 72)  648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 28, 28, 72)  288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_68 (ReLU)                (None, 28, 28, 72)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 28, 28, 24)  1728        ['re_lu_68[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 28, 28, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 28, 28, 88)  2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 28, 28, 88)  352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_69 (ReLU)                (None, 28, 28, 88)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 28, 28, 88)  792         ['re_lu_69[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 28, 28, 88)  352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_70 (ReLU)                (None, 28, 28, 88)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 28, 28, 24)  2112        ['re_lu_70[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 28, 28, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 28, 28, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 28, 28, 96)  2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 28, 28, 96)  384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_56 (TFOpL  (None, 28, 28, 96)  0           ['expanded_conv_3/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_71 (ReLU)                (None, 28, 28, 96)   0           ['tf.__operators__.add_56[0][0]']
#
#  tf.math.multiply_56 (TFOpLambd  (None, 28, 28, 96)  0           ['re_lu_71[0][0]']
#  a)
#
#  multiply_37 (Multiply)         (None, 28, 28, 96)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_56[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 31, 31, 96)  0           ['multiply_37[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 14, 14, 96)  2400        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 14, 14, 96)  384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_57 (TFOpL  (None, 14, 14, 96)  0           ['expanded_conv_3/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_72 (ReLU)                (None, 14, 14, 96)   0           ['tf.__operators__.add_57[0][0]']
#
#  tf.math.multiply_57 (TFOpLambd  (None, 14, 14, 96)  0           ['re_lu_72[0][0]']
#  a)
#
#  multiply_38 (Multiply)         (None, 14, 14, 96)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_57[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_38[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_58 (TFOpL  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_73 (ReLU)                (None, 1, 1, 96)     0           ['tf.__operators__.add_58[0][0]']
#
#  tf.math.multiply_58 (TFOpLambd  (None, 1, 1, 96)    0           ['re_lu_73[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, 14, 14, 96)  0           ['multiply_38[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_58[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 14, 14, 40)  3840        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 14, 14, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 14, 14, 240)  9600       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 14, 14, 240)  960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_59 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_4/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_74 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_59[0][0]']
#
#  tf.math.multiply_59 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_74[0][0]']
#  a)
#
#  multiply_39 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_59[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 14, 14, 240)  6000       ['multiply_39[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 14, 14, 240)  960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_60 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_4/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_75 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_60[0][0]']
#
#  tf.math.multiply_60 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_75[0][0]']
#  a)
#
#  multiply_40 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_60[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_40[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_61 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_76 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_61[0][0]']
#
#  tf.math.multiply_61 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_76[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, 14, 14, 240)  0          ['multiply_40[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_61[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 14, 14, 40)  9600        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 14, 14, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 14, 14, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 14, 14, 240)  9600       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 14, 14, 240)  960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_62 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_5/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_77 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_62[0][0]']
#
#  tf.math.multiply_62 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_77[0][0]']
#  a)
#
#  multiply_41 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_62[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 14, 14, 240)  6000       ['multiply_41[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 14, 14, 240)  960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_63 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_5/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_78 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_63[0][0]']
#
#  tf.math.multiply_63 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_78[0][0]']
#  a)
#
#  multiply_42 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_63[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_42[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_64 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_79 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_64[0][0]']
#
#  tf.math.multiply_64 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_79[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 14, 14, 240)  0          ['multiply_42[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_64[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 14, 14, 40)  9600        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 14, 14, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 14, 14, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 14, 14, 120)  4800       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 14, 14, 120)  480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_65 (TFOpL  (None, 14, 14, 120)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_80 (ReLU)                (None, 14, 14, 120)  0           ['tf.__operators__.add_65[0][0]']
#
#  tf.math.multiply_65 (TFOpLambd  (None, 14, 14, 120)  0          ['re_lu_80[0][0]']
#  a)
#
#  multiply_43 (Multiply)         (None, 14, 14, 120)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_65[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 14, 14, 120)  3000       ['multiply_43[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 14, 14, 120)  480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_66 (TFOpL  (None, 14, 14, 120)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_81 (ReLU)                (None, 14, 14, 120)  0           ['tf.__operators__.add_66[0][0]']
#
#  tf.math.multiply_66 (TFOpLambd  (None, 14, 14, 120)  0          ['re_lu_81[0][0]']
#  a)
#
#  multiply_44 (Multiply)         (None, 14, 14, 120)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_66[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_44[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_67 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_82 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_67[0][0]']
#
#  tf.math.multiply_67 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_82[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, 14, 14, 120)  0          ['multiply_44[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_67[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 14, 14, 48)  5760        ['expanded_conv_6/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, 14, 14, 48)  192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 14, 14, 144)  6912       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 14, 14, 144)  576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_68 (TFOpL  (None, 14, 14, 144)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_83 (ReLU)                (None, 14, 14, 144)  0           ['tf.__operators__.add_68[0][0]']
#
#  tf.math.multiply_68 (TFOpLambd  (None, 14, 14, 144)  0          ['re_lu_83[0][0]']
#  a)
#
#  multiply_45 (Multiply)         (None, 14, 14, 144)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_68[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 14, 14, 144)  3600       ['multiply_45[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 14, 14, 144)  576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_69 (TFOpL  (None, 14, 14, 144)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_84 (ReLU)                (None, 14, 14, 144)  0           ['tf.__operators__.add_69[0][0]']
#
#  tf.math.multiply_69 (TFOpLambd  (None, 14, 14, 144)  0          ['re_lu_84[0][0]']
#  a)
#
#  multiply_46 (Multiply)         (None, 14, 14, 144)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_69[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_46[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_70 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_85 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_70[0][0]']
#
#  tf.math.multiply_70 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_85[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, 14, 14, 144)  0          ['multiply_46[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_70[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 14, 14, 48)  6912        ['expanded_conv_7/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, 14, 14, 48)  192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 14, 14, 48)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 14, 14, 288)  13824      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 14, 14, 288)  1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_71 (TFOpL  (None, 14, 14, 288)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_86 (ReLU)                (None, 14, 14, 288)  0           ['tf.__operators__.add_71[0][0]']
#
#  tf.math.multiply_71 (TFOpLambd  (None, 14, 14, 288)  0          ['re_lu_86[0][0]']
#  a)
# ...
#
#  expanded_conv_9/expand (Conv2D  (None, 7, 7, 576)   55296       ['expanded_conv_8/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_9/expand/BatchNo  (None, 7, 7, 576)   2304        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_74 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_89 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_74[0][0]']
#
#  tf.math.multiply_74 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_89[0][0]']
#  a)
#
#  multiply_49 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_74[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 7, 7, 576)   14400       ['multiply_49[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 7, 7, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_75 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_90 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_75[0][0]']
#
#  tf.math.multiply_75 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_90[0][0]']
#  a)
#
#  multiply_50 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_75[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_50[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_76 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_91 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_76[0][0]']
#
#  tf.math.multiply_76 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_91[0][0]']
#  a)
#
#  expanded_conv_9/squeeze_excite  (None, 7, 7, 576)   0           ['multiply_50[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_76[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 7, 7, 96)    55296       ['expanded_conv_9/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, 7, 7, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 7, 7, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 7, 7, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 7, 7, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_77 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_92 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_77[0][0]']
#
#  tf.math.multiply_77 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_92[0][0]']
#  a)
#
#  multiply_51 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_77[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 7, 7, 576)   14400       ['multiply_51[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 7, 7, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_78 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_93 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_78[0][0]']
#
#  tf.math.multiply_78 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_93[0][0]']
#  a)
#
#  multiply_52 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_78[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_52[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_79 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_94 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_79[0][0]']
#
#  tf.math.multiply_79 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_94[0][0]']
#  a)
#
#  expanded_conv_10/squeeze_excit  (None, 7, 7, 576)   0           ['multiply_52[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_79[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 7, 7, 96)    55296       ['expanded_conv_10/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, 7, 7, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 7, 7, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_80 (TFOpL  (None, 7, 7, 576)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_95 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_80[0][0]']
#
#  tf.math.multiply_80 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_95[0][0]']
#  a)
#
#  multiply_53 (Multiply)         (None, 7, 7, 576)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_80[0][0]']
#
# ==================================================================================================
# Total params: 939,120
# Trainable params: 927,008
# Non-trainable params: 12,112
# __________________________________________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable = False
last_output = base_model.layers[-1].output
x = layers.GlobalMaxPooling2D()(last_output)
x = layers.BatchNormalization()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(50, activation='softmax')(x)
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 224, 224, 3)  0           ['input_3[0][0]']
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['rescaling_2[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add_54 (TFOpL  (None, 112, 112, 16  0          ['Conv/BatchNorm[0][0]']
#  ambda)                         )
#
#  re_lu_64 (ReLU)                (None, 112, 112, 16  0           ['tf.__operators__.add_54[0][0]']
#                                 )
#
#  tf.math.multiply_54 (TFOpLambd  (None, 112, 112, 16  0          ['re_lu_64[0][0]']
#  a)                             )
#
#  multiply_36 (Multiply)         (None, 112, 112, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply_54[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, 113, 113, 16  0          ['multiply_36[0][0]']
#  eroPadding2D)                  )
#
#  expanded_conv/depthwise (Depth  (None, 56, 56, 16)  144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
#  expanded_conv/depthwise/BatchN  (None, 56, 56, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_65 (ReLU)                (None, 56, 56, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_65[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_55 (TFOpL  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  ambda)                                                          nv_1[0][0]']
#
#  re_lu_66 (ReLU)                (None, 1, 1, 16)     0           ['tf.__operators__.add_55[0][0]']
#
#  tf.math.multiply_55 (TFOpLambd  (None, 1, 1, 16)    0           ['re_lu_66[0][0]']
#  a)
#
#  expanded_conv/squeeze_excite/M  (None, 56, 56, 16)  0           ['re_lu_65[0][0]',
#  ul (Multiply)                                                    'tf.math.multiply_55[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 56, 56, 16)  256         ['expanded_conv/squeeze_excite/Mu
#                                                                  l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 56, 56, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv_1/expand (Conv2D  (None, 56, 56, 72)  1152        ['expanded_conv/project/BatchNorm
#  )                                                               [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_67 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 57, 57, 72)  0           ['re_lu_67[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 28, 28, 72)  648         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 28, 28, 72)  288         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_68 (ReLU)                (None, 28, 28, 72)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 28, 28, 24)  1728        ['re_lu_68[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 28, 28, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 28, 28, 88)  2112        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 28, 28, 88)  352         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_69 (ReLU)                (None, 28, 28, 88)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 28, 28, 88)  792         ['re_lu_69[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 28, 28, 88)  352         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_70 (ReLU)                (None, 28, 28, 88)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 28, 28, 24)  2112        ['re_lu_70[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 28, 28, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 28, 28, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 28, 28, 96)  2304        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 28, 28, 96)  384         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_56 (TFOpL  (None, 28, 28, 96)  0           ['expanded_conv_3/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_71 (ReLU)                (None, 28, 28, 96)   0           ['tf.__operators__.add_56[0][0]']
#
#  tf.math.multiply_56 (TFOpLambd  (None, 28, 28, 96)  0           ['re_lu_71[0][0]']
#  a)
#
#  multiply_37 (Multiply)         (None, 28, 28, 96)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_56[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 31, 31, 96)  0           ['multiply_37[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 14, 14, 96)  2400        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 14, 14, 96)  384         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_57 (TFOpL  (None, 14, 14, 96)  0           ['expanded_conv_3/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_72 (ReLU)                (None, 14, 14, 96)   0           ['tf.__operators__.add_57[0][0]']
#
#  tf.math.multiply_57 (TFOpLambd  (None, 14, 14, 96)  0           ['re_lu_72[0][0]']
#  a)
#
#  multiply_38 (Multiply)         (None, 14, 14, 96)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_57[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_38[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_58 (TFOpL  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_73 (ReLU)                (None, 1, 1, 96)     0           ['tf.__operators__.add_58[0][0]']
#
#  tf.math.multiply_58 (TFOpLambd  (None, 1, 1, 96)    0           ['re_lu_73[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, 14, 14, 96)  0           ['multiply_38[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_58[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 14, 14, 40)  3840        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 14, 14, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 14, 14, 240)  9600       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 14, 14, 240)  960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_59 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_4/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_74 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_59[0][0]']
#
#  tf.math.multiply_59 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_74[0][0]']
#  a)
#
#  multiply_39 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_59[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 14, 14, 240)  6000       ['multiply_39[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 14, 14, 240)  960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_60 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_4/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_75 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_60[0][0]']
#
#  tf.math.multiply_60 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_75[0][0]']
#  a)
#
#  multiply_40 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_60[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_40[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_61 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_76 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_61[0][0]']
#
#  tf.math.multiply_61 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_76[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, 14, 14, 240)  0          ['multiply_40[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_61[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 14, 14, 40)  9600        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 14, 14, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 14, 14, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 14, 14, 240)  9600       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 14, 14, 240)  960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_62 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_5/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_77 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_62[0][0]']
#
#  tf.math.multiply_62 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_77[0][0]']
#  a)
#
#  multiply_41 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_62[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 14, 14, 240)  6000       ['multiply_41[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 14, 14, 240)  960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_63 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_5/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_78 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_63[0][0]']
#
#  tf.math.multiply_63 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_78[0][0]']
#  a)
#
#  multiply_42 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_63[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_42[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_64 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_79 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_64[0][0]']
#
#  tf.math.multiply_64 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_79[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 14, 14, 240)  0          ['multiply_42[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_64[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 14, 14, 40)  9600        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 14, 14, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 14, 14, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 14, 14, 120)  4800       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 14, 14, 120)  480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_65 (TFOpL  (None, 14, 14, 120)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_80 (ReLU)                (None, 14, 14, 120)  0           ['tf.__operators__.add_65[0][0]']
#
#  tf.math.multiply_65 (TFOpLambd  (None, 14, 14, 120)  0          ['re_lu_80[0][0]']
#  a)
#
#  multiply_43 (Multiply)         (None, 14, 14, 120)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_65[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, 14, 14, 120)  3000       ['multiply_43[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_6/depthwise/Batc  (None, 14, 14, 120)  480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_66 (TFOpL  (None, 14, 14, 120)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_81 (ReLU)                (None, 14, 14, 120)  0           ['tf.__operators__.add_66[0][0]']
#
#  tf.math.multiply_66 (TFOpLambd  (None, 14, 14, 120)  0          ['re_lu_81[0][0]']
#  a)
#
#  multiply_44 (Multiply)         (None, 14, 14, 120)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_66[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_44[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_67 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_82 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_67[0][0]']
#
#  tf.math.multiply_67 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_82[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, 14, 14, 120)  0          ['multiply_44[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_67[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 14, 14, 48)  5760        ['expanded_conv_6/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, 14, 14, 48)  192         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 14, 14, 144)  6912       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 14, 14, 144)  576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_68 (TFOpL  (None, 14, 14, 144)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_83 (ReLU)                (None, 14, 14, 144)  0           ['tf.__operators__.add_68[0][0]']
#
#  tf.math.multiply_68 (TFOpLambd  (None, 14, 14, 144)  0          ['re_lu_83[0][0]']
#  a)
#
#  multiply_45 (Multiply)         (None, 14, 14, 144)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_68[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 14, 14, 144)  3600       ['multiply_45[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 14, 14, 144)  576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_69 (TFOpL  (None, 14, 14, 144)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_84 (ReLU)                (None, 14, 14, 144)  0           ['tf.__operators__.add_69[0][0]']
#
#  tf.math.multiply_69 (TFOpLambd  (None, 14, 14, 144)  0          ['re_lu_84[0][0]']
#  a)
#
#  multiply_46 (Multiply)         (None, 14, 14, 144)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_69[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_46[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_70 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_85 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_70[0][0]']
#
#  tf.math.multiply_70 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_85[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, 14, 14, 144)  0          ['multiply_46[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_70[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 14, 14, 48)  6912        ['expanded_conv_7/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, 14, 14, 48)  192         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 14, 14, 48)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 14, 14, 288)  13824      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 14, 14, 288)  1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_71 (TFOpL  (None, 14, 14, 288)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_86 (ReLU)                (None, 14, 14, 288)  0           ['tf.__operators__.add_71[0][0]']
#
#  tf.math.multiply_71 (TFOpLambd  (None, 14, 14, 288)  0          ['re_lu_86[0][0]']
#  a)
# ...
#  re_lu_89 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_74[0][0]']
#
#  tf.math.multiply_74 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_89[0][0]']
#  a)
#
#  multiply_49 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_74[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 7, 7, 576)   14400       ['multiply_49[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 7, 7, 576)   2304        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_75 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_90 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_75[0][0]']
#
#  tf.math.multiply_75 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_90[0][0]']
#  a)
#
#  multiply_50 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_75[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_50[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_76 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_91 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_76[0][0]']
#
#  tf.math.multiply_76 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_91[0][0]']
#  a)
#
#  expanded_conv_9/squeeze_excite  (None, 7, 7, 576)   0           ['multiply_50[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_76[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 7, 7, 96)    55296       ['expanded_conv_9/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, 7, 7, 96)    384         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 7, 7, 96)     0           ['expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 7, 7, 576)   55296       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 7, 7, 576)   2304        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_77 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_92 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_77[0][0]']
#
#  tf.math.multiply_77 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_92[0][0]']
#  a)
#
#  multiply_51 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_77[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 7, 7, 576)   14400       ['multiply_51[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 7, 7, 576)   2304        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_78 (TFOpL  (None, 7, 7, 576)   0           ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_93 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_78[0][0]']
#
#  tf.math.multiply_78 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_93[0][0]']
#  a)
#
#  multiply_52 (Multiply)         (None, 7, 7, 576)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_78[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_52[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_79 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_94 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_79[0][0]']
#
#  tf.math.multiply_79 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_94[0][0]']
#  a)
#
#  expanded_conv_10/squeeze_excit  (None, 7, 7, 576)   0           ['multiply_52[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_79[0][0]']
#
#  expanded_conv_10/project (Conv  (None, 7, 7, 96)    55296       ['expanded_conv_10/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, 7, 7, 96)    384         ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_10/Add (Add)     (None, 7, 7, 96)     0           ['expanded_conv_9/Add[0][0]',
#                                                                   'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 576)    55296       ['expanded_conv_10/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 576)   2304        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_80 (TFOpL  (None, 7, 7, 576)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_95 (ReLU)                (None, 7, 7, 576)    0           ['tf.__operators__.add_80[0][0]']
#
#  tf.math.multiply_80 (TFOpLambd  (None, 7, 7, 576)   0           ['re_lu_95[0][0]']
#  a)
#
#  multiply_53 (Multiply)         (None, 7, 7, 576)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_80[0][0]']
#
#  global_max_pooling2d_6 (Global  (None, 576)         0           ['multiply_53[0][0]']
#  MaxPooling2D)
#
#  batch_normalization_6 (BatchNo  (None, 576)         2304        ['global_max_pooling2d_6[0][0]']
#  rmalization)
#
#  dense_14 (Dense)               (None, 512)          295424      ['batch_normalization_6[0][0]']
#
#  dense_15 (Dense)               (None, 50)           25650       ['dense_14[0][0]']
#
# ==================================================================================================
# Total params: 1,262,498
# Trainable params: 322,226
# Non-trainable params: 940,272
# __________________________________________________________________________________________________

# %%
history = model.fit(train_img, train_labels, batch_size=32, validation_data=(val_img, val_labels), epochs=12)
# Out:
# Epoch 1/12
# 46/46 [==============================] - 8s 69ms/step - loss: 3.5399 - acc: 0.1572 - val_loss: 4.7073 - val_acc: 0.0600
# Epoch 2/12
# 46/46 [==============================] - 2s 43ms/step - loss: 2.1943 - acc: 0.4862 - val_loss: 4.0317 - val_acc: 0.1400
# Epoch 3/12
# 46/46 [==============================] - 2s 43ms/step - loss: 1.6346 - acc: 0.6248 - val_loss: 3.4431 - val_acc: 0.2000
# Epoch 4/12
# 46/46 [==============================] - 2s 42ms/step - loss: 1.2870 - acc: 0.7007 - val_loss: 3.0200 - val_acc: 0.2800
# Epoch 5/12
# 46/46 [==============================] - 2s 42ms/step - loss: 1.0200 - acc: 0.7683 - val_loss: 2.6916 - val_acc: 0.3400
# Epoch 6/12
# 46/46 [==============================] - 2s 42ms/step - loss: 0.8521 - acc: 0.8083 - val_loss: 2.3467 - val_acc: 0.3400
# Epoch 7/12
# 46/46 [==============================] - 2s 42ms/step - loss: 0.6982 - acc: 0.8462 - val_loss: 2.3066 - val_acc: 0.3000
# Epoch 8/12
# 46/46 [==============================] - 2s 43ms/step - loss: 0.6045 - acc: 0.8669 - val_loss: 2.2316 - val_acc: 0.4000
# Epoch 9/12
# 46/46 [==============================] - 2s 44ms/step - loss: 0.5091 - acc: 0.8931 - val_loss: 2.2581 - val_acc: 0.4000
# Epoch 10/12
# 46/46 [==============================] - 2s 42ms/step - loss: 0.4217 - acc: 0.9124 - val_loss: 2.3018 - val_acc: 0.4400
# Epoch 11/12
# 46/46 [==============================] - 2s 45ms/step - loss: 0.3624 - acc: 0.9262 - val_loss: 2.4506 - val_acc: 0.4600
# Epoch 12/12
# 46/46 [==============================] - 2s 41ms/step - loss: 0.3427 - acc: 0.9297 - val_loss: 2.3802 - val_acc: 0.4600

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch for %d samples per category' % samples_by_category)
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.ylim([0, 1])
plt.legend(['train', 'test'], loc='right')
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy by epoch for %d samples per category' % samples_by_category)
plt.ylabel('accuracy')
plt.ylim([0, 1])
plt.legend(['train', 'test'], loc='right')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ---------------------------------------------------

# %% [markdown]
# **Training model**
#
# https://www.tensorflow.org/tutorials/images/cnn
#
# https://github.com/deepseasw/caltech101-image-cnn-classification/blob/master/Image%20CNN%20Classification.ipynb

# %%
# functions to load the data
# def load_batch_images(path, n_examples_train, n_examples_validation=2, max_imgs_by_class=30, nb_categories=4, resize_to_size=(224,224)):

def load_batch_images(path, n_examples_train, n_examples_validation=2, max_imgs_by_class=30, nb_categories=4, resize_to_size=(224,224)):

    images_train = []
    labels_train = []
    images_validation = []
    labels_validation = []
    
    # Get categories from path
    categories_list = os.listdir(path)
    categories_list = [category for category in categories_list if category != '.DS_Store']
    if isinstance(nb_categories, int) and len(categories_list) >= nb_categories:
        categories_list = categories_list[0:nb_categories]

    # For each category...
    for idx, category in enumerate(categories_list):
        # ... get images in category ...
        images_list = os.listdir(os.path.join(path, category))        
        if len(images_list) > max_imgs_by_class:
            images_list = images_list[:max_imgs_by_class]
        
        indx = 0
        for images in images_list[:n_examples_train + n_examples_validation]:                
            # ... load them ...
            img = load_img(os.path.join(path, category, images))  # as PIL images
            img = img_to_array(img)                               # as numpy array
            img = misc.imresize(img, resize_to_size)              # resize
            # img = misc.imrotate(img, 180)
            if indx < n_examples_train:
                images_train.append(img)
                labels_train.append(idx)
            else:
                images_validation.append(img)
                labels_validation.append(idx)
            indx += 1
    
    # Convert to one-hot
    labels_train = np_utils.to_categorical(labels_train)
    labels_validation = np_utils.to_categorical(labels_validation)

    return images_train, labels_train, images_validation, labels_validation

# %%
def shuffle_dataset(a, b):
    """Shuffle the entire dataset"""
    assert np.shape(a)[0] == np.shape(b)[0]
    p = np.random.permutation(np.shape(a)[0])
    return (a[p], b[p])

# %%
# def get_data(samples_by_category=8, dataset_path="./101_ObjectCategories/", nb_categories=4):
def get_data(samples_by_category=8, dataset_path="./101_ObjectCategories/", nb_categories=4):

    images_train, labels_train, images_validation, labels_validation = load_batch_images(path=dataset_path,n_examples_train=samples_by_category, n_examples_validation=20, max_imgs_by_class=30, nb_categories=nb_categories)

    images_train = np.float64(images_train)
    images_validation = np.float64(images_validation)

    images_train = preprocess_input(images_train)  # substract the mean RGB channels of the imagenet dataset. This is because the Inception model we are using has been trained on a different dataset (imagenet dataset)
    images_validation = preprocess_input(images_validation)

    if not USE_TENSORFLOW_AS_BACKEND:
        images_validation = images_validation.swapaxes(1, 3).swapaxes(2, 3)
        images_train = images_train.swapaxes(1, 3).swapaxes(2, 3)

    train = shuffle_dataset(np.asarray(images_train), labels_train)
    validation = shuffle_dataset(np.asarray(images_validation), labels_validation)

    images_train, labels_train = train
    images_validation, labels_validation = validation

    return images_train, labels_train, train, images_validation, labels_validation, validation

# %%
nb_categories = 50  #4         # out of 101 classes
samples_by_category = 29  #10  # out of about 50 images for each category

# Load the data!
train_img, train_labels, train, val_img, val_labels, val = get_data(
    samples_by_category=samples_by_category, dataset_path='./101_ObjectCategories/', nb_categories=nb_categories)

# # Normalize pixel values to be between 0 and 1
# train_img, val_img = train_img / 255.0, val_img / 255.0

# Print the tensors shapes
print('Shapes (train) :', train_img[0].shape, train_labels[0].shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
# Shapes (train) : (224, 224, 3) (50,)

# %%
len(train_img)
# Out:
# 1450

# %%
#conv로 블록을 계속 쌓으면 인풋이 뭐였는지 까먹는다
#그래서 인풋에 들어간것을 중간에 concatenate해줌 (residual, resnet)

# #input
# model = models.Sequential()
# model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
# model.add(layers.BatchNormalization())
# # model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.MaxPool2D())

# #blocks
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.BatchNormalization())
# # model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.MaxPool2D())
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.BatchNormalization())
# # model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.MaxPool2D())
# model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# model.add(layers.BatchNormalization())
# # model.add(tf.keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.MaxPool2D())


model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', 
                        input_shape=(224, 224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))   

model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.BatchNormalization())
model.add(layers.Dense(50, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dropout (Dropout)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dense_1 (Dense)             (None, 50)                6450
#
# =================================================================
# Total params: 11,175,410
# Trainable params: 11,175,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # output
# # model.add(layers.Flatten())
# model.add(layers.GlobalAvgPool2D())
# # model.add(layers.Dense(2048, activation='softmax'))
# model.add(layers.Dense(128, activation='relu'))
# # tf.keras.layers.Dropout(0.2),
# model.add(layers.Dense(20))

# %%
# model.summary()

# %%
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# model.compile(optimizer='adam',
#               loss=tf.keras.losses.sparse_categorical_crossentropy(from_logits=True),
#               metrics=['acc'])
# model.compile(optimizer='adam', loss=tf.keras.losses.sparse_categorical_crossentropy(from_logits=True), metrics=['acc'])
# from keras.optimizers import SGD

# opt = SGD(lr=0.01)
# model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics = ['acc'])

# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])
# optimizer=sgd (지금은 안 쓰여짐)
# train the model on the new data for a few epochs
history = model.fit(train_img, train_labels,batch_size=2, validation_data=(val_img, val_labels), epochs=12)
# Out:
# Epoch 1/12
# 725/725 [==============================] - 27s 24ms/step - loss: 4.0052 - acc: 0.0248 - val_loss: 3.8802 - val_acc: 0.0200
# Epoch 2/12
# 725/725 [==============================] - 18s 24ms/step - loss: 3.6632 - acc: 0.1228 - val_loss: 3.5053 - val_acc: 0.1800
# Epoch 3/12
# 725/725 [==============================] - 17s 24ms/step - loss: 2.5793 - acc: 0.3717 - val_loss: 3.2288 - val_acc: 0.1600
# Epoch 4/12
# 725/725 [==============================] - 17s 23ms/step - loss: 1.3679 - acc: 0.6469 - val_loss: 3.5075 - val_acc: 0.3600
# Epoch 5/12
# 725/725 [==============================] - 17s 23ms/step - loss: 0.6897 - acc: 0.8317 - val_loss: 3.9557 - val_acc: 0.3400
# Epoch 6/12
# 725/725 [==============================] - 17s 23ms/step - loss: 0.3801 - acc: 0.9269 - val_loss: 7.9730 - val_acc: 0.3000
# Epoch 7/12
# 725/725 [==============================] - 17s 23ms/step - loss: 0.2842 - acc: 0.9455 - val_loss: 10.0508 - val_acc: 0.3000
# Epoch 8/12
# 725/725 [==============================] - 17s 23ms/step - loss: 0.2632 - acc: 0.9593 - val_loss: 10.5674 - val_acc: 0.2800
# Epoch 9/12
# 725/725 [==============================] - 17s 24ms/step - loss: 0.1501 - acc: 0.9759 - val_loss: 15.9761 - val_acc: 0.3200
# Epoch 10/12
# 725/725 [==============================] - 17s 23ms/step - loss: 0.3413 - acc: 0.9655 - val_loss: 14.8126 - val_acc: 0.2600
# Epoch 11/12
# 725/725 [==============================] - 17s 24ms/step - loss: 0.2275 - acc: 0.9703 - val_loss: 22.8163 - val_acc: 0.3000
# Epoch 12/12
# 725/725 [==============================] - 17s 24ms/step - loss: 0.3107 - acc: 0.9717 - val_loss: 22.7463 - val_acc: 0.2400

# %%
plt.plot(history.history['acc'], label='accuracy')
plt.plot(history.history['val_acc'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(val_img,  val_labels, verbose=2)
# Out:
# 2/2 - 1s - loss: 22.7463 - acc: 0.2400 - 914ms/epoch - 457ms/step

# %%
print(test_acc)
# Out:
# 0.23999999463558197

# %% [markdown]
# ----------------------------------------
# ---------------------------------------

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_img[i])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    # plt.xlabel([train_labels[i][0]])
plt.show()

# %%
# for showing separarate images
image = train_img[39]
plt.imshow(image)
plt.show()
